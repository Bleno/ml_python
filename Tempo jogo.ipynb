# %%
import pandas as pd

# %%
dados = pd.read_csv('tempo_jogo.csv', sep=';')

# %%
dados
# Out:
#      Outlook  Temperature Temperature.1  Humidity Humidity.1  Windy Play
# 0   overcast           83           hot        86       high  False  yes
# 1   overcast           64          cool        65     normal   True  yes
# 2   overcast           72          mild        90       high   True  yes
# 3   overcast           81           hot        75     normal  False  yes
# 4      rainy           70          mild        96       high  False  yes
# 5      rainy           68          cool        80     normal  False  yes
# 6      rainy           65          cool        70     normal   True   no
# 7      rainy           75          mild        80     normal  False  yes
# 8      rainy           71          mild        91       high   True   no
# 9      sunny           85           hot        85       high  False   no
# 10     sunny           80           hot        90       high   True   no
# 11     sunny           72          mild        95       high  False   no
# 12     sunny           69          cool        70     normal  False  yes
# 13     sunny           75          mild        70     normal   True  yes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
# Outlook          14 non-null object
# Temperature      14 non-null int64
# Temperature.1    14 non-null object
# Humidity         14 non-null int64
# Humidity.1       14 non-null object
# Windy            14 non-null bool
# Play             14 non-null object
# dtypes: bool(1), int64(2), object(4)
# memory usage: 814.0+ bytes

# %%
dados.Outlook.unique()
# Out:
# array(['overcast', 'rainy', 'sunny'], dtype=object)

# %%
sub_dados = dados.copy()

# %%
dict_outlook = {'overcast': 0, 'rainy': 1, 'sunny': 2}
for i in range(0, len(sub_dados)):
    sub_dados.loc[i, 'Outlook'] = dict_outlook[sub_dados.loc[i, 'Outlook']]

# %%
for i in range(0, len(sub_dados)):
    if sub_dados.loc[i, 'Play'] == 'yes':
        sub_dados.loc[i, 'Play'] = 1
    else:
        sub_dados.loc[i, 'Play'] = 0

# %%
sub_dados
# Out:
#     Outlook  Temperature Temperature.1  Humidity Humidity.1  Windy  Play
# 0         0           83           hot        86       high  False     1
# 1         0           64          cool        65     normal   True     1
# 2         0           72          mild        90       high   True     1
# 3         0           81           hot        75     normal  False     1
# 4         1           70          mild        96       high  False     1
# 5         1           68          cool        80     normal  False     1
# 6         1           65          cool        70     normal   True     0
# 7         1           75          mild        80     normal  False     1
# 8         1           71          mild        91       high   True     0
# 9         2           85           hot        85       high  False     0
# 10        2           80           hot        90       high   True     0
# 11        2           72          mild        95       high  False     0
# 12        2           69          cool        70     normal  False     1
# 13        2           75          mild        70     normal   True     1

# %%
x = sub_dados.loc[:,['Outlook', 'Temperature', 'Humidity', 'Windy']]
x
# Out:
#     Outlook  Temperature  Humidity  Windy
# 0         0           83        86  False
# 1         0           64        65   True
# 2         0           72        90   True
# 3         0           81        75  False
# 4         1           70        96  False
# 5         1           68        80  False
# 6         1           65        70   True
# 7         1           75        80  False
# 8         1           71        91   True
# 9         2           85        85  False
# 10        2           80        90   True
# 11        2           72        95  False
# 12        2           69        70  False
# 13        2           75        70   True

# %%
y = sub_dados.loc[:,['Play']]
y
# Out:
#     Play
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# 6      0
# 7      1
# 8      0
# 9      0
# 10     0
# 11     0
# 12     1
# 13     1

# %%
sub_dados.sample(5)
# Out:
#     Outlook  Temperature Temperature.1  Humidity Humidity.1  Windy  Play
# 13        2           75          mild        70     normal   True     1
# 8         1           71          mild        91       high   True     0
# 6         1           65          cool        70     normal   True     0
# 2         0           72          mild        90       high   True     1
# 3         0           81           hot        75     normal  False     1

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_test, y_treino, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_treino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 8 to 6
# Data columns (total 4 columns):
# Outlook        9 non-null int64
# Temperature    9 non-null int64
# Humidity       9 non-null int64
# Windy          9 non-null bool
# dtypes: bool(1), int64(3)
# memory usage: 297.0 bytes

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 9 to 5
# Data columns (total 4 columns):
# Outlook        5 non-null int64
# Temperature    5 non-null int64
# Humidity       5 non-null int64
# Windy          5 non-null bool
# dtypes: bool(1), int64(3)
# memory usage: 165.0 bytes

# %%
x_treino
# Out:
#     Outlook  Temperature  Humidity  Windy
# 8         1           71        91   True
# 2         0           72        90   True
# 1         0           64        65   True
# 13        2           75        70   True
# 4         1           70        96  False
# 7         1           75        80  False
# 10        2           80        90   True
# 3         0           81        75  False
# 6         1           65        70   True

# %%
y_treino
# Out:
#     Play
# 8      0
# 2      1
# 1      1
# 13     1
# 4      1
# 7      1
# 10     0
# 3      1
# 6      0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(x, y)

# %%
dt
# Out:
# DecisionTreeClassifier(class_weight=None,
#                        criterion=    Outlook  Temperature  Humidity  Windy
# 0         0           83        86  False
# 1         0           64        65   True
# 2         0           72        90   True
# 3         0           81        75  False
# 4         1           70        96  False
# 5         1           68        80  False
# 6         1           65        70   True
# 7         1           75        80  False
# 8         1           71        91   True
# 9         2           85        85  False
# 10        2           80        90   True
# 11        2           72        95  False
# 12        2           69        70  False
# 13        2           75        70   True,
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None,
#                        splitter=    Play
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# 6      0
# 7      1
# 8      0
# 9      0
# 10     0
# 11     0
# 12     1
# 13     1)

# %%
dt.fit(x_treino, y_treino)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-10e5b1b0e056> in <module>
# ----> 1 dt.fit(x_treino, y_treino)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     342         if not isinstance(criterion, Criterion):
#     343             if is_classification:
# --> 344                 criterion = CRITERIA_CLF[self.criterion](self.n_outputs_,
#     345                                                          self.n_classes_)
#     346             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1884         raise TypeError(
#    1885             "{0!r} objects are mutable, thus they cannot be"
# -> 1886             " hashed".format(self.__class__.__name__)
#    1887         )
#    1888
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed
